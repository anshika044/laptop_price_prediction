# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 131543: invalid continuation byte
# when we get this error, try assigning the encoding format to latin

# %%
df=pd.read_csv("/content/drive/MyDrive/MITT AI ML 2024/Dataset/laptop_price (1).csv",encoding='latin-1')
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df.drop(columns=['laptop_ID'],inplace=True)

# %%
df.isnull().sum()
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 28

# %%
df.drop_duplicates(inplace=True,ignore_index=True)

# %%
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1270  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1271  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1272  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# 1271  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1272                                    1366x768
# 1273                                    1366x768
# 1274                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1270            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1271            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1272  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1273            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1274  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1270         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1271         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1272             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1273            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1274             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1275 rows x 12 columns]

# %%
df['Price_euros']
# Out:
# 0       1339.69
# 1        898.94
# 2        575.00
# 3       2537.45
# 4       1803.60
#          ...
# 1270     638.00
# 1271    1499.00
# 1272     229.00
# 1273     764.00
# 1274     369.00
# Name: Price_euros, Length: 1275, dtype: float64

# %%
df['Price']=(df['Price_euros']*87.91).astype('int')
# Price converted from Euros to INR

# %%
df.drop(columns=['Price_euros'],inplace=True)

# %%
df.sample(2)
# Out:
#     Company                  Product   TypeName  Inches   ScreenResolution  \
# 815  Lenovo           Thinkpad T470s  Ultrabook    14.0  Full HD 1920x1080
# 227    Asus  Vivobook X541UV-DM1217T   Notebook    15.6  Full HD 1920x1080
#
#                             Cpu  Ram     Memory                    Gpu  \
# 815  Intel Core i7 7500U 2.7GHz  8GB  256GB SSD  Intel HD Graphics 620
# 227  Intel Core i5 7200U 2.5GHz  8GB  256GB SSD  Nvidia GeForce 920MX
#
#           OpSys  Weight   Price
# 815  Windows 10  1.32kg  163424
# 227  Windows 10     2kg   67602

# %%
# EDA and data cleaning and preprocessing
# For every column, we will clean it, perform preprocessing and then perform Univariate analysis
# and then perform bivariate analysis of that column with respect to Output column(Price column)

# %%
# Company
df['Company'].value_counts()
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         152
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
9+7+7+6+4+4+3+3+3+3+2
# Out:
# 51

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df=df[df.groupby('Company').Company.transform('count')>20].copy()

# %%
df.sample(5)
# Out:
#      Company                                     Product            TypeName  \
# 379     Acer                                    Aspire 7            Notebook
# 107     Asus  UX430UQ-GV209R (i7-7500U/8GB/256GB/GeForce           Ultrabook
# 39        HP                                 ProBook 450            Notebook
# 1249    Dell                                      XPS 13  2 in 1 Convertible
# 657     Dell                               Inspiron 5570            Notebook
#
#       Inches                  ScreenResolution                          Cpu  \
# 379     15.6                 Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 107     14.0       IPS Panel Full HD 1920x1080   Intel Core i7 7500U 2.7GHz
# 39      15.6                 Full HD 1920x1080   Intel Core i5 8250U 1.6GHz
# 1249    13.3  Quad HD+ / Touchscreen 3200x1800    Intel Core i5 7Y54 1.2GHz
# 657     15.6                 Full HD 1920x1080   Intel Core i7 8550U 1.8GHz
#
#        Ram                Memory                      Gpu       OpSys  Weight  \
# 379    8GB               1TB HDD  Nvidia GeForce GTX 1050       Linux   2.4kg
# 107    8GB             256GB SSD     Nvidia GeForce 940MX  Windows 10   1.3kg
# 39     8GB             256GB SSD    Nvidia GeForce 930MX   Windows 10   2.1kg
# 1249   8GB             256GB SSD    Intel HD Graphics 615  Windows 10  1.24kg
# 657   16GB  256GB SSD +  2TB HDD           AMD Radeon 530  Windows 10   2.2kg
#
#        Price
# 379    74371
# 107   104876
# 39     77272
# 1249  159380
# 657    99777

# %%
df.shape
# Out:
# (1224, 12)

# %%
1275-1224
# Out:
# 51

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
# Product

# %%
df['Product'].value_counts()
# Out:
# Product
# XPS 13                                 30
# Inspiron 3567                          25
# 250 G6                                 21
# Legion Y520-15IKBN                     19
# Vostro 3568                            19
#                                        ..
# Ideapad 520-15IKBR                      1
# Thinkpad X260                           1
# Rog G752VL-UH71T                        1
# Portege X30-D-10L                       1
# X553SA-XX031T (N3050/4GB/500GB/W10)     1
# Name: count, Length: 589, dtype: int64

# %%
df.drop(columns=['Product'],inplace=True)

# %%
df.sample(2)
# Out:
#     Company            TypeName  Inches       ScreenResolution  \
# 693  Lenovo  2 in 1 Convertible    14.0  Touchscreen 2560x1440
# 836    Asus              Gaming    17.3      Full HD 1920x1080
#
#                              Cpu   Ram                Memory  \
# 693   Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 836  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
#
#                          Gpu       OpSys  Weight   Price
# 693    Intel HD Graphics 620  Windows 10  1.42kg  227686
# 836  Nvidia GeForce GTX 1070  Windows 10   2.9kg  212654

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              688
# Gaming                200
# Ultrabook             171
# 2 in 1 Convertible    114
# Workstation            29
# Netbook                22
# Name: count, dtype: int64

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
# Inches
df['Inches'].value_counts()
# Out:
# Inches
# 15.6    637
# 14.0    182
# 17.3    162
# 13.3    152
# 12.5     37
# 11.6     29
# 12.0      6
# 13.9      6
# 15.4      4
# 10.1      4
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# 15.0      1
# Name: count, dtype: int64

# %%
df['Inches'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Inches'>

# %%
sns.displot(df['Inches'],kde=True)

# %%
sns.barplot(x=df['Inches'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                492
# 1366x768                                         258
# IPS Panel Full HD 1920x1080                      217
# IPS Panel Full HD / Touchscreen 1920x1080         48
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     10
# 4K Ultra HD / Touchscreen 3840x2160                8
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ / Touchscreen 3200x1800         4
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Quad HD+ 2560x1440                       3
# 2560x1440                                          3
# Quad HD+ 3200x1800                                 3
# IPS Panel Quad HD+ 3200x1800                       2
# 1920x1080                                          2
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / Full HD 1920x1080                    1
# Name: count, dtype: int64

# %%
# X_res
# Y_res
# Touchscreen
# IPS panel

# %%
a="IPS Panel 4K Ultra HD / Touchscreen 3840x2160"

# %%
a
# Out:
# 'IPS Panel 4K Ultra HD / Touchscreen 3840x2160'

# %%
a.split()
# Out:
# ['IPS', 'Panel', '4K', 'Ultra', 'HD', '/', 'Touchscreen', '3840x2160']

# %%
a.split()[-1]
# Out:
# '3840x2160'

# %%
a.split()[-1].split('x')
# Out:
# ['3840', '2160']

# %%
a.split()[-1].split('x')[0]
# Out:
# '3840'

# %%
a.split()[-1].split('x')[1]
# Out:
# '2160'

# %%
(lambda a:a.split()[-1].split('x')[0])(a)
# Out:
# '3840'

# %%
df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[0])
# Out:
# 0       2560
# 1       1440
# 2       1920
# 3       2880
# 4       2560
#         ...
# 1270    1920
# 1271    3200
# 1272    1366
# 1273    1366
# 1274    1366
# Name: ScreenResolution, Length: 1224, dtype: object

# %%
df['X_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[0]).astype('int')
df['Y_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[1]).astype('int')

# %%
a="IPS Panel 4K Ultra HD / Touchscreen 3840x2160"

# %%
(lambda a:1 if "Touchscreen" in a else 0)(a)
# Out:
# 1

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda a:1 if "Touchscreen" in a else 0)
df['IPS']=df['ScreenResolution'].apply(lambda a:1 if "IPS" in a else 0)

# %%
df.sample(5)
# Out:
#       Company   TypeName  Inches                  ScreenResolution  \
# 1200     Dell   Notebook    15.6                          1366x768
# 1054     Dell  Ultrabook    13.3  Quad HD+ / Touchscreen 3200x1800
# 1111     Dell   Notebook    15.6                          1366x768
# 872   Toshiba   Notebook    15.6       IPS Panel Full HD 1920x1080
# 1233      MSI     Gaming    17.3                 Full HD 1920x1080
#
#                               Cpu   Ram                Memory  \
# 1200   Intel Core i3 6006U 2.0GHz   4GB             128GB SSD
# 1054   Intel Core i7 7500U 2.7GHz  16GB               1TB SSD
# 1111   Intel Core i5 6200U 2.3GHz   4GB             500GB HDD
# 872    Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 1233  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
#
#                           Gpu       OpSys  Weight   Price  X_res  Y_res  \
# 1200       AMD Radeon R7 M440  Windows 10   2.3kg   43867   1366    768
# 1054    Intel HD Graphics 620  Windows 10   1.2kg  198149   3200   1800
# 1111       AMD Radeon R5 M315   Windows 7  2.24kg   67615   1366    768
# 872     Intel HD Graphics 620  Windows 10   2.0kg  122019   1920   1080
# 1233  Nvidia GeForce GTX 1060  Windows 10   2.7kg  140480   1920   1080
#
#       Touchscreen  IPS
# 1200            0    0
# 1054            1    0
# 1111            0    0
# 872             0    1
# 1233            0    0

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.sample(5)
# Out:
#      Company  TypeName  Inches                          Cpu   Ram  \
# 1071      HP  Notebook    15.6   Intel Core i5 6200U 2.3GHz   4GB
# 1109    Asus    Gaming    15.6  Intel Core i7 6700HQ 2.6GHz  16GB
# 1229     MSI    Gaming    15.6  Intel Core i7 7700HQ 2.8GHz   8GB
# 334     Asus    Gaming    15.6  Intel Core i7 7700HQ 2.8GHz   8GB
# 735   Lenovo  Notebook    15.6   Intel Core i7 7500U 2.7GHz   4GB
#
#                     Memory                      Gpu       OpSys  Weight  \
# 1071             500GB HDD    Intel HD Graphics 520  Windows 10  2.31kg
# 1109  128GB SSD +  1TB HDD  Nvidia GeForce GTX 960M  Windows 10  2.59kg
# 1229  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1050  Windows 10   2.2kg
# 334              256GB SSD  Nvidia GeForce GTX 1050  Windows 10   2.5kg
# 735                1TB HDD    Intel HD Graphics 620  Windows 10  1.85kg
#
#        Price  X_res  Y_res  Touchscreen  IPS
# 1071  105404   1366    768            0    0
# 1109  117711   1920   1080            0    1
# 1229  101008   1920   1080            0    0
# 334    87822   1920   1080            0    0
# 735    68481   1920   1080            0    0

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz     183
# Intel Core i7 7700HQ 2.8GHz    142
# Intel Core i7 7500U 2.7GHz     124
# Intel Core i7 8550U 1.8GHz      71
# Intel Core i5 8250U 1.6GHz      71
#                               ...
# AMD E-Series E2-9000 2.2GHz      1
# Intel Core M M3-6Y30 0.9GHz      1
# Intel Core i5 2.9GHz             1
# Intel Atom x5-Z8350 1.44GHz      1
# AMD A9-Series 9410 2.9GHz        1
# Name: count, Length: 111, dtype: int64

# %%
a="Intel Core i5 7200U 2.5GHz"

# %%
a.split()
# Out:
# ['Intel', 'Core', 'i5', '7200U', '2.5GHz']

# %%
a.split()[0:3]
# Out:
# ['Intel', 'Core', 'i5']

# %%
" ".join(a.split()[0:3])
# Out:
# 'Intel Core i5'

# %%
(lambda a:" ".join(a.split()[0:3]))(a)
# Out:
# 'Intel Core i5'

# %%
df['Cpu']=df['Cpu'].apply(lambda a:" ".join(a.split()[0:3]))

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i7               493
# Intel Core i5               411
# Intel Core i3               134
# Intel Celeron Dual           66
# Intel Pentium Quad           27
# Intel Core M                 16
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Celeron Quad            5
# Intel Atom x5-Z8550           4
# AMD A8-Series 7410            4
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD A10-Series 9600P          2
# Intel Xeon E3-1535M           2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A6-Series A6-9220         2
# AMD A10-Series A10-9620P      2
# Intel Xeon E3-1505M           2
# AMD E-Series E2-9000e         2
# AMD E-Series 9000e            1
# AMD Ryzen 1600                1
# AMD E-Series 6110             1
# AMD FX 9830P                  1
# AMD E-Series E2-6110          1
# AMD E-Series E2-9000          1
# AMD A6-Series 7310            1
# Intel Atom x5-Z8350           1
# AMD A12-Series 9700P          1
# AMD A4-Series 7210            1
# AMD FX 8800P                  1
# AMD E-Series 9000             1
# AMD A9-Series 9410            1
# Name: count, dtype: int64

# %%
def fetch_processor_name(text):
    if text=="Intel Core i7" or text=="Intel Core i5" or text=="Intel Core i3" or text=="Intel Core M":
        return text
    elif text.split()[0]=="Intel":
        return " ".join(text.split()[0:2])
    elif text.split()[0]=="AMD":
        if text[4]=="A":
            return "AMD A-Series"
        elif text[4]=="E":
            return "AMD E-Series"
        elif text[4]=="F":
            return "AMD F-Series"
        elif text[4]=="R":
            return "AMD Ryzen Series"
        else:
            return "Other AMD Processor"
    else:
        return "Other Processor"

# %%
df['CPU']=df['Cpu'].apply(fetch_processor_name)

# %%
df['CPU'].value_counts()
# Out:
# CPU
# Intel Core i7       493
# Intel Core i5       411
# Intel Core i3       134
# Intel Celeron        71
# AMD A-Series         45
# Intel Pentium        30
# Intel Core M         16
# AMD E-Series          9
# Intel Atom            5
# AMD Ryzen Series      4
# Intel Xeon            4
# AMD F-Series          2
# Name: count, dtype: int64

# %%
df.drop(columns=['Cpu'],inplace=True)

# %%
df.sample(2)
# Out:
#      Company            TypeName  Inches  Ram     Memory  \
# 1043  Lenovo            Notebook    15.6  8GB  256GB SSD
# 158     Dell  2 in 1 Convertible    15.6  8GB  256GB SSD
#
#                          Gpu       OpSys  Weight  Price  X_res  Y_res  \
# 1043   Intel HD Graphics 520  Windows 10   2.3kg  92270   1920   1080
# 158   Intel UHD Graphics 620  Windows 10  1.56kg  92217   1920   1080
#
#       Touchscreen  IPS            CPU
# 1043            0    0  Intel Core i5
# 158             1    0  Intel Core i7

# %%
df['CPU'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='CPU'>

# %%
sns.barplot(x=df['CPU'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['Ram']
# Out:
# 0        8GB
# 1        8GB
# 2        8GB
# 3       16GB
# 4        8GB
#         ...
# 1270     4GB
# 1271    16GB
# 1272     2GB
# 1273     6GB
# 1274     4GB
# Name: Ram, Length: 1224, dtype: object

# %%
df['Ram']=df['Ram'].apply(lambda x:x.replace("GB","")).astype('int')

# %%
df['Ram']
# Out:
# 0        8
# 1        8
# 2        8
# 3       16
# 4        8
#         ..
# 1270     4
# 1271    16
# 1272     2
# 1273     6
# 1274     4
# Name: Ram, Length: 1224, dtype: int64

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8     595
# 4     351
# 16    186
# 6      34
# 12     25
# 32     15
# 2      14
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      265
# Intel HD Graphics 520      179
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     65
# Nvidia GeForce GTX 1060     45
#                           ...
# Intel Graphics 620           1
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# Nvidia GeForce 960M          1
# Name: count, Length: 108, dtype: int64

# %%
df['Gpu']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel     666
# Nvidia    385
# AMD       173
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Gpu'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1011
# No OS             63
# Linux             58
# Windows 7         45
# Chrome OS         22
# macOS             13
# Mac OS X           8
# Android            2
# Windows 10 S       2
# Name: count, dtype: int64

# %%
def os(text):
    if text=="Windows 10" or text=="Windows 10 S":
        return "Windows 10"
    elif text=="macOS" or text=="Mac OS X":
        return "Mac OS"
    elif text=="Windows 7":
        return text
    elif text=="No OS":
        return text
    else:
        return "Linux/Android/Chrome OS"

# %%
df['OpSys']=df['OpSys'].apply(os)

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10                 1013
# Linux/Android/Chrome OS      82
# No OS                        63
# Windows 7                    45
# Mac OS                       21
# Name: count, dtype: int64

# %%
df['OpSys'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='OpSys'>

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['Weight']
# Out:
# 0       1.37kg
# 1       1.34kg
# 2       1.86kg
# 3       1.83kg
# 4       1.37kg
#          ...
# 1270     1.8kg
# 1271     1.3kg
# 1272     1.5kg
# 1273    2.19kg
# 1274     2.2kg
# Name: Weight, Length: 1224, dtype: object

# %%
df['Weight']=df['Weight'].apply(lambda x:x.replace("kg","")).astype('float')

# %%
df['Weight'].describe()
# Out:
# count    1224.000000
# mean        2.063204
# std         0.663863
# min         0.690000
# 25%         1.597500
# 50%         2.060000
# 75%         2.320000
# max         4.700000
# Name: Weight, dtype: float64

# %%
sns.displot(x=df['Weight'],kde=True)
plt.show()

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
# Memory

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        393
# 1TB HDD                          214
# 500GB HDD                        124
# 512GB SSD                        105
# 128GB SSD +  1TB HDD              93
# 256GB SSD +  1TB HDD              73
# 128GB SSD                         71
# 32GB Flash Storage                29
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           12
# 64GB Flash Storage                10
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 1.0TB Hybrid                       7
# 16GB Flash Storage                 6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 32GB SSD                           2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  512GB SSD             1
# 512GB SSD +  256GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 64GB SSD                           1
# 1TB HDD +  1TB HDD                 1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
# SSD
# HDD
# Hybrid
# Flash Storage

# %%
df['Memory']=df['Memory'].astype(str).replace("\.0","",regex=True)

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        393
# 1TB HDD                          215
# 500GB HDD                        124
# 512GB SSD                        105
# 128GB SSD +  1TB HDD              93
# 256GB SSD +  1TB HDD              73
# 128GB SSD                         71
# 32GB Flash Storage                29
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           12
# 64GB Flash Storage                10
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 1TB Hybrid                         7
# 16GB Flash Storage                 6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 1TB SSD +  1TB HDD                 2
# 512GB Flash Storage                2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  500GB HDD             2
# 256GB SSD +  256GB SSD             2
# 32GB SSD                           2
# 128GB HDD                          1
# 512GB SSD +  1TB Hybrid            1
# 8GB SSD                            1
# 240GB SSD                          1
# 508GB Hybrid                       1
# 512GB SSD +  256GB SSD             1
# 1TB HDD +  1TB HDD                 1
# 64GB Flash Storage +  1TB HDD      1
# 512GB SSD +  512GB SSD             1
# 64GB SSD                           1
# 256GB SSD +  1TB Hybrid            1
# Name: count, dtype: int64

# %%
df['Memory']=df['Memory'].str.replace("TB","000")
df['Memory']=df['Memory'].str.replace("GB","")

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256 SSD                         393
# 1000 HDD                        215
# 500 HDD                         124
# 512 SSD                         105
# 128 SSD +  1000 HDD              93
# 256 SSD +  1000 HDD              73
# 128 SSD                          71
# 32 Flash Storage                 29
# 2000 HDD                         16
# 512 SSD +  1000 HDD              14
# 1000 SSD                         12
# 64 Flash Storage                 10
# 256 SSD +  2000 HDD              10
# 256 Flash Storage                 8
# 1000 Hybrid                       7
# 16 Flash Storage                  6
# 180 SSD                           5
# 128 Flash Storage                 4
# 16 SSD                            3
# 512 SSD +  2000 HDD               3
# 1000 SSD +  1000 HDD              2
# 512 Flash Storage                 2
# 128 SSD +  2000 HDD               2
# 256 SSD +  500 HDD                2
# 256 SSD +  256 SSD                2
# 32 SSD                            2
# 128 HDD                           1
# 512 SSD +  1000 Hybrid            1
# 8 SSD                             1
# 240 SSD                           1
# 508 Hybrid                        1
# 512 SSD +  256 SSD                1
# 1000 HDD +  1000 HDD              1
# 64 Flash Storage +  1000 HDD      1
# 512 SSD +  512 SSD                1
# 64 SSD                            1
# 256 SSD +  1000 Hybrid            1
# Name: count, dtype: int64

# %%
new=df['Memory'].str.split('+',n=1,expand=True)
df['first']=new[0]
df['first']=df['first'].str.strip()
df['second']=new[1]

df['Layer1HDD']=df['first'].apply(lambda x:1 if "HDD" in x else 0)
df['Layer1SSD']=df['first'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer1Hybrid']=df['first'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer1Flash_Storage']=df['first'].apply(lambda x:1 if "Flash Storage" in x else 0)

df['first']=df['first'].str.replace(r'\D','',regex=True)

df['second'].fillna("0",inplace=True)

df['second']=df['second'].str.strip()
df['Layer2HDD']=df['second'].apply(lambda x:1 if "HDD" in x else 0)
df['Layer2SSD']=df['second'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer2Hybrid']=df['second'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer2Flash_Storage']=df['second'].apply(lambda x:1 if "Flash Storage" in x else 0)

df['second']=df['second'].str.replace(r'\D','',regex=True)

df['first']=df['first'].astype('int')
df['second']=df['second'].astype('int')

df['HDD']=df['first']*df['Layer1HDD']+df['second']*df['Layer2HDD']
df['SSD']=df['first']*df['Layer1SSD']+df['second']*df['Layer2SSD']
df['Hybrid']=df['first']*df['Layer1Hybrid']+df['second']*df['Layer2Hybrid']
df['Flash_Storage']=df['first']*df['Layer1Flash_Storage']+df['second']*df['Layer2Flash_Storage']

df.drop(columns=['first','second','Layer1HDD','Layer1SSD','Layer1Hybrid','Layer1Flash_Storage',
                 'Layer2HDD','Layer2SSD','Layer2Hybrid','Layer2Flash_Storage'],inplace=True)

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches  Ram    Memory     Gpu       OpSys  Weight  \
# 299     Asus  Ultrabook    15.6   16   512 SSD  Nvidia  Windows 10    1.63
# 1111    Dell   Notebook    15.6    4   500 HDD     AMD   Windows 7    2.24
# 860   Lenovo   Notebook    15.6    8  1000 HDD   Intel  Windows 10    2.30
# 417       HP  Ultrabook    14.0    8   256 SSD   Intel  Windows 10    1.43
# 351       HP   Notebook    15.6    8   256 SSD   Intel  Windows 10    1.84
#
#        Price  X_res  Y_res  Touchscreen  IPS            CPU   HDD  SSD  \
# 299   129051   1920   1080            0    0  Intel Core i7     0  512
# 1111   67615   1366    768            0    0  Intel Core i5   500    0
# 860    74781   1920   1080            0    1  Intel Core i5  1000    0
# 417   131865   1920   1080            0    0  Intel Core i7     0  256
# 351   114634   1920   1080            0    0  Intel Core i7     0  256
#
#       Hybrid  Flash_Storage
# 299        0              0
# 1111       0              0
# 860        0              0
# 417        0              0
# 351        0              0

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.sample(3)
# Out:
#      Company     TypeName  Inches  Ram     Gpu       OpSys  Weight   Price  \
# 327     Asus    Ultrabook    15.6    8  Nvidia  Windows 10    1.70   92296
# 1228  Lenovo       Gaming    15.6   16  Nvidia  Windows 10    2.60   90459
# 1143      HP  Workstation    15.6    8  Nvidia   Windows 7    2.59  195951
#
#       X_res  Y_res  Touchscreen  IPS            CPU   HDD  SSD  Hybrid  \
# 327    1920   1080            0    0  Intel Core i7     0  256       0
# 1228   1920   1080            1    1  Intel Core i7  1000  128       0
# 1143   1920   1080            0    1  Intel Core i7     0  256       0
#
#       Flash_Storage
# 327               0
# 1228              0
# 1143              0

# %%
df.corr(numeric_only=True)
# Out:
#                  Inches       Ram    Weight     Price     X_res     Y_res  \
# Inches         1.000000  0.239155  0.824959  0.055330 -0.057739 -0.071772
# Ram            0.239155  1.000000  0.394187  0.726639  0.415731  0.412278
# Weight         0.824959  0.394187  1.000000  0.212038 -0.025155 -0.036765
# Price          0.055330  0.726639  0.212038  1.000000  0.553707  0.552964
# X_res         -0.057739  0.415731 -0.025155  0.553707  1.000000  0.997454
# Y_res         -0.071772  0.412278 -0.036765  0.552964  0.997454  1.000000
# Touchscreen   -0.359497  0.094037 -0.291506  0.161443  0.320954  0.317174
# IPS           -0.104090  0.223322  0.038753  0.289226  0.283969  0.294360
# HDD            0.525077  0.106175  0.503765 -0.093770 -0.109044 -0.115936
# SSD           -0.114322  0.589636 -0.063144  0.654751  0.523882  0.518090
# Hybrid         0.050989  0.052774  0.105129  0.025523 -0.000097 -0.000967
# Flash_Storage -0.230659 -0.047725 -0.178962 -0.023384 -0.013602  0.020131
#
#                Touchscreen       IPS       HDD       SSD    Hybrid  \
# Inches           -0.359497 -0.104090  0.525077 -0.114322  0.050989
# Ram               0.094037  0.223322  0.106175  0.589636  0.052774
# Weight           -0.291506  0.038753  0.503765 -0.063144  0.105129
# Price             0.161443  0.289226 -0.093770  0.654751  0.025523
# X_res             0.320954  0.283969 -0.109044  0.523882 -0.000097
# Y_res             0.317174  0.294360 -0.115936  0.518090 -0.000967
# Touchscreen       1.000000  0.154500 -0.195492  0.240469 -0.035892
# IPS               0.154500  1.000000 -0.087397  0.228186 -0.013349
# HDD              -0.195492 -0.087397  1.000000 -0.407685 -0.073848
# SSD               0.240469  0.228186 -0.407685  1.000000 -0.050250
# Hybrid           -0.035892 -0.013349 -0.073848 -0.050250  1.000000
# Flash_Storage    -0.012073  0.074771 -0.112475 -0.140474 -0.012602
#
#                Flash_Storage
# Inches             -0.230659
# Ram                -0.047725
# Weight             -0.178962
# Price              -0.023384
# X_res              -0.013602
# Y_res               0.020131
# Touchscreen        -0.012073
# IPS                 0.074771
# HDD                -0.112475
# SSD                -0.140474
# Hybrid             -0.012602
# Flash_Storage       1.000000

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches           0.055330
# Ram              0.726639
# Weight           0.212038
# Price            1.000000
# X_res            0.553707
# Y_res            0.552964
# Touchscreen      0.161443
# IPS              0.289226
# HDD             -0.093770
# SSD              0.654751
# Hybrid           0.025523
# Flash_Storage   -0.023384
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.sample(2)
# Out:
#      Company            TypeName  Inches  Ram     Gpu       OpSys  Weight  \
# 1194    Dell  2 in 1 Convertible    13.3    8   Intel  Windows 10    1.60
# 1047     MSI              Gaming    17.3   16  Nvidia  Windows 10    3.78
#
#        Price  X_res  Y_res  Touchscreen  IPS            CPU   HDD  SSD
# 1194  105404   1920   1080            1    1  Intel Core i5     0  256
# 1047  135877   1920   1080            0    1  Intel Core i7  1000  256

# %%
df['HDD'].value_counts()
# Out:
# HDD
# 0       667
# 1000    398
# 500     126
# 2000     32
# 128       1
# Name: count, dtype: int64

# %%
df['HDD'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='HDD'>

# %%
sns.barplot(x=df['HDD'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['SSD'].value_counts()
# Out:
# SSD
# 256     479
# 0       425
# 128     166
# 512     125
# 1000     14
# 180       5
# 16        3
# 32        2
# 64        1
# 1024      1
# 768       1
# 240       1
# 8         1
# Name: count, dtype: int64

# %%
df['SSD'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SSD'>

# %%
sns.barplot(x=df['SSD'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.055330
# Ram            0.726639
# Weight         0.212038
# Price          1.000000
# X_res          0.553707
# Y_res          0.552964
# Touchscreen    0.161443
# IPS            0.289226
# HDD           -0.093770
# SSD            0.654751
# Name: Price, dtype: float64

# %%
# X_res: number of pixels placed on the screen horizontally
# Y_res: number of pixels placed on the screen vertically
# screen size
# Pixel Density(ppi)

# %%
df['PPI']=((df['X_res']**2)+(df['Y_res']**2))**0.5/df['Inches']
df['PPI']=round(df['PPI'],2)

# %%
df.sample(15)
# Out:
#      Company            TypeName  Inches  Ram     Gpu  \
# 584     Dell             Netbook    11.6    4   Intel
# 1098      HP            Notebook    15.6    4   Intel
# 880       HP  2 in 1 Convertible    13.3    4   Intel
# 416     Dell            Notebook    13.3    4   Intel
# 784   Lenovo           Ultrabook    14.0   16   Intel
# 736       HP         Workstation    15.6   16  Nvidia
# 1240  Lenovo            Notebook    15.6    6     AMD
# 44      Dell  2 in 1 Convertible    17.3   12  Nvidia
# 357     Dell              Gaming    15.6    8  Nvidia
# 275     Dell            Notebook    15.6   12   Intel
# 15     Apple           Ultrabook    13.3    8   Intel
# 61      Dell           Ultrabook    14.0    8   Intel
# 898     Dell            Notebook    15.6    4     AMD
# 22        HP            Notebook    15.6    4     AMD
# 724      MSI              Gaming    17.3    8  Nvidia
#
#                         OpSys  Weight   Price  X_res  Y_res  Touchscreen  IPS  \
# 584   Linux/Android/Chrome OS    1.26   25933   1366    768            0    0
# 1098               Windows 10    1.96   43955   1366    768            0    0
# 880                Windows 10    1.28  149447   1920   1080            1    0
# 416                Windows 10    1.65   60569   1366    768            0    0
# 784                Windows 10    1.70  202105   1920   1080            0    0
# 736                Windows 10    2.60  212654   1920   1080            0    0
# 1240               Windows 10    2.20   52532   1920   1080            0    0
# 44                 Windows 10    2.77   87822   1920   1080            1    0
# 357                Windows 10    2.65   87822   1920   1080            0    0
# 275                Windows 10    2.30   62685   1366    768            0    0
# 15                     Mac OS    1.37  133495   2560   1600            0    1
# 61                 Windows 10    1.70   77272   1920   1080            0    0
# 898                Windows 10    2.18   53976   1366    768            0    0
# 22                      No OS    1.86   22680   1366    768            0    0
# 724                Windows 10    2.70  118544   1920   1080            0    0
#
#                 CPU   HDD  SSD     PPI
# 584   Intel Celeron     0    0  135.09
# 1098  Intel Pentium  1000    0  100.45
# 880   Intel Core i5     0  256  165.63
# 416   Intel Core i3     0  128  117.83
# 784   Intel Core i7     0  512  157.35
# 736   Intel Core i7     0  256  141.21
# 1240   AMD A-Series     0  256  141.21
# 44    Intel Core i5  1000    0  127.34
# 357   Intel Core i5  1000    0  141.21
# 275   Intel Core i7  1000    0  100.45
# 15    Intel Core i5     0  256  226.98
# 61    Intel Core i5     0  256  157.35
# 898   Intel Core i3  1000    0  100.45
# 22     AMD E-Series   500    0  100.45
# 724   Intel Core i7  1000  128  127.34

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.055330
# Ram            0.726639
# Weight         0.212038
# Price          1.000000
# X_res          0.553707
# Y_res          0.552964
# Touchscreen    0.161443
# IPS            0.289226
# HDD           -0.093770
# SSD            0.654751
# PPI            0.483787
# Name: Price, dtype: float64

# %%
df.drop(columns=['X_res','Y_res','Inches'],inplace=True)

# %%
df.sample(3)
# Out:
#      Company  TypeName  Ram     Gpu                    OpSys  Weight   Price  \
# 1263    Acer  Notebook    4   Intel  Linux/Android/Chrome OS     2.4   25405
# 770     Dell  Notebook   16     AMD               Windows 10     2.3  103845
# 1161     MSI    Gaming   16  Nvidia               Windows 10     1.7  155512
#
#       Touchscreen  IPS            CPU   HDD  SSD     PPI
# 1263            0    0  Intel Celeron   500    0  100.45
# 770             0    0  Intel Core i7     0  256  141.21
# 1161            0    0  Intel Core i7  1000  256  157.35

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# 0    1055
# 1     169
# Name: count, dtype: int64

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['IPS'].value_counts()
# Out:
# IPS
# 0    885
# 1    339
# Name: count, dtype: int64

# %%
df['IPS'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='IPS'>

# %%
sns.barplot(x=df['IPS'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['PPI'].describe()
# Out:
# count    1224.000000
# mean      145.675874
# std        42.045198
# min        90.580000
# 25%       127.340000
# 50%       141.210000
# 75%       157.350000
# max       352.470000
# Name: PPI, dtype: float64

# %%
df.sample(3)
# Out:
#      Company  TypeName  Ram     Gpu                    OpSys  Weight   Price  \
# 272     Dell  Notebook    8     AMD  Linux/Android/Chrome OS    2.14   64620
# 1247    Asus    Gaming   16  Nvidia               Windows 10    2.34  204390
# 396   Lenovo  Notebook    8     AMD               Windows 10    2.10  108090
#
#       Touchscreen  IPS            CPU   HDD  SSD     PPI
# 272             0    0  Intel Core i7     0  256  141.21
# 1247            0    1  Intel Core i7  1000  256  141.21
# 396             0    1  Intel Core i7     0  256  141.21

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Ram            0.726639
# Weight         0.212038
# Price          1.000000
# Touchscreen    0.161443
# IPS            0.289226
# HDD           -0.093770
# SSD            0.654751
# PPI            0.483787
# Name: Price, dtype: float64

# %%
X=df.drop(columns=['Price'])
y=np.log(df['Price'])

# %%
df.to_csv("laptop_data_processed.csv",index=False)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=42)

# %%
X.shape
# Out:
# (1224, 12)

# %%
X_train.shape
# Out:
# (1040, 12)

# %%
X_test.shape
# Out:
# (184, 12)

# %%
0.85*1224
# Out:
# 1040.3999999999999

# %%
1224-1040
# Out:
# 184

# %%
X
# Out:
#      Company            TypeName  Ram    Gpu       OpSys  Weight  Touchscreen  \
# 0      Apple           Ultrabook    8  Intel      Mac OS    1.37            0
# 1      Apple           Ultrabook    8  Intel      Mac OS    1.34            0
# 2         HP            Notebook    8  Intel       No OS    1.86            0
# 3      Apple           Ultrabook   16    AMD      Mac OS    1.83            0
# 4      Apple           Ultrabook    8  Intel      Mac OS    1.37            0
# ...      ...                 ...  ...    ...         ...     ...          ...
# 1270  Lenovo  2 in 1 Convertible    4  Intel  Windows 10    1.80            1
# 1271  Lenovo  2 in 1 Convertible   16  Intel  Windows 10    1.30            1
# 1272  Lenovo            Notebook    2  Intel  Windows 10    1.50            0
# 1273      HP            Notebook    6    AMD  Windows 10    2.19            0
# 1274    Asus            Notebook    4  Intel  Windows 10    2.20            0
#
#       IPS            CPU   HDD  SSD     PPI
# 0       1  Intel Core i5     0  128  226.98
# 1       0  Intel Core i5     0    0  127.68
# 2       0  Intel Core i5     0  256  141.21
# 3       1  Intel Core i7     0  512  220.53
# 4       1  Intel Core i5     0  256  226.98
# ...   ...            ...   ...  ...     ...
# 1270    1  Intel Core i7     0  128  157.35
# 1271    1  Intel Core i7     0  512  276.05
# 1272    0  Intel Celeron     0    0  111.94
# 1273    0  Intel Core i7  1000    0  100.45
# 1274    0  Intel Celeron   500    0  100.45
#
# [1224 rows x 12 columns]

# %%
X_train
# Out:
#      Company            TypeName  Ram     Gpu       OpSys  Weight  \
# 249    Apple           Ultrabook    8   Intel      Mac OS    1.37
# 453   Lenovo            Notebook    8   Intel  Windows 10    1.65
# 200     Dell              Gaming   16  Nvidia  Windows 10    2.65
# 227     Asus            Notebook    8  Nvidia  Windows 10    2.00
# 189     Dell            Notebook    8     AMD  Windows 10    2.80
# ...      ...                 ...  ...     ...         ...     ...
# 1091      HP            Notebook    4   Intel       No OS    1.86
# 1144      HP  2 in 1 Convertible    8   Intel  Windows 10    1.48
# 1179      HP            Notebook    4   Intel  Windows 10    2.07
# 903   Lenovo           Ultrabook    8   Intel  Windows 10    1.13
# 1175    Asus            Notebook    4   Intel  Windows 10    2.00
#
#       Touchscreen  IPS            CPU   HDD  SSD     PPI
# 249             0    1  Intel Core i5     0  512  226.98
# 453             0    0  Intel Core i5     0  256  157.35
# 200             0    1  Intel Core i7  1000  512  282.42
# 227             0    0  Intel Core i5     0  256  141.21
# 189             0    0  Intel Core i7  1000  128  127.34
# ...           ...  ...            ...   ...  ...     ...
# 1091            0    0  Intel Core i3  1000    0  100.45
# 1144            1    0  Intel Core i7     0  256  220.84
# 1179            0    0  Intel Core i3   500    0  100.45
# 903             0    1  Intel Core i7     0    0  157.35
# 1175            0    0  Intel Core i3     0  256  157.35
#
# [1040 rows x 12 columns]

# %%
y_train
# Out:
# 249     12.097016
# 453     11.680455
# 200     11.996542
# 227     11.121393
# 189     11.465645
#           ...
# 1091    10.322691
# 1144    11.971299
# 1179    10.953277
# 903     12.101417
# 1175    11.121393
# Name: Price, Length: 1040, dtype: float64

# %%
X_test
# Out:
#      Company            TypeName  Ram     Gpu                    OpSys  \
# 691   Lenovo            Notebook    4   Intel               Windows 10
# 229       HP            Notebook    8     AMD               Windows 10
# 158     Dell  2 in 1 Convertible    8   Intel               Windows 10
# 707   Lenovo         Workstation   16  Nvidia                Windows 7
# 956     Dell  2 in 1 Convertible    8   Intel               Windows 10
# ...      ...                 ...  ...     ...                      ...
# 838   Lenovo            Notebook    4   Intel  Linux/Android/Chrome OS
# 637   Lenovo            Notebook    2   Intel               Windows 10
# 359     Dell            Notebook    8   Intel               Windows 10
# 1188    Dell           Ultrabook    8   Intel  Linux/Android/Chrome OS
# 969   Lenovo            Notebook    6  Nvidia               Windows 10
#
#       Weight  Touchscreen  IPS            CPU   HDD  SSD     PPI
# 691     1.70            0    0  Intel Core i5     0  256  157.35
# 229     1.90            0    0  Intel Core i7  1000    0  141.21
# 158     1.56            1    0  Intel Core i7     0  256  141.21
# 707     2.18            0    0  Intel Core i7     0  512  141.21
# 956     1.24            1    0  Intel Core i5     0  256  165.63
# ...      ...          ...  ...            ...   ...  ...     ...
# 838     1.50            0    0  Intel Celeron     0    0  111.94
# 637     1.42            0    0  Intel Celeron     0    0  111.94
# 359     1.36            0    0  Intel Core i5     0  256  157.35
# 1188    1.23            1    0  Intel Core i5     0  256  276.05
# 969     2.40            0    0  Intel Core i5     0  256  141.21
#
# [184 rows x 12 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
X_train.sample()
# Out:
#     Company  TypeName  Ram    Gpu       OpSys  Weight  Touchscreen  IPS  \
# 739    Acer  Notebook    4  Intel  Windows 10     2.4            0    0
#
#                CPU  HDD  SSD     PPI
# 739  Intel Core i3  500    0  100.45

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1040 entries, 249 to 1175
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1040 non-null   object
#  1   TypeName     1040 non-null   object
#  2   Ram          1040 non-null   int64
#  3   Gpu          1040 non-null   object
#  4   OpSys        1040 non-null   object
#  5   Weight       1040 non-null   float64
#  6   Touchscreen  1040 non-null   int64
#  7   IPS          1040 non-null   int64
#  8   CPU          1040 non-null   object
#  9   HDD          1040 non-null   int64
#  10  SSD          1040 non-null   int64
#  11  PPI          1040 non-null   float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 105.6+ KB

# %%
# LinearRegression
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,4,8])
    ],remainder='passthrough')
step2=LinearRegression()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)
print("R2 score:",round(r2_score(y_test,y_pred),4))
print("MAE:",round(mean_absolute_error(y_test,y_pred),4))
print("MSE:",round(mean_squared_error(y_test,y_pred),4))
# Out:
# R2 score: 0.8122
# MAE: 0.1963
# MSE: 0.0593

# %%
# LassoRegression
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,4,8])
    ],remainder='passthrough')
step2=Lasso(alpha=0.0001)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)
print("R2 score:",round(r2_score(y_test,y_pred),4))
print("MAE:",round(mean_absolute_error(y_test,y_pred),4))
print("MSE:",round(mean_squared_error(y_test,y_pred),4))
# Out:
# R2 score: 0.8126
# MAE: 0.1957
# MSE: 0.0592

# %%
# RidgeRegression
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,4,8])
    ],remainder='passthrough')
step2=Ridge(alpha=0.1)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)
print("R2 score:",round(r2_score(y_test,y_pred),4))
print("MAE:",round(mean_absolute_error(y_test,y_pred),4))
print("MSE:",round(mean_squared_error(y_test,y_pred),4))
# Out:
# R2 score: 0.812
# MAE: 0.1964
# MSE: 0.0594

# %%
# KNeighborsRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,4,8])
    ],remainder='passthrough')
step2=KNeighborsRegressor()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)
print("R2 score:",round(r2_score(y_test,y_pred),4))
print("MAE:",round(mean_absolute_error(y_test,y_pred),4))
print("MSE:",round(mean_squared_error(y_test,y_pred),4))
# Out:
# R2 score: 0.763
# MAE: 0.1998
# MSE: 0.0748

# %%
# DecisionTreeRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,4,8])
    ],remainder='passthrough')
step2=DecisionTreeRegressor(max_depth=8)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)
print("R2 score:",round(r2_score(y_test,y_pred),4))
print("MAE:",round(mean_absolute_error(y_test,y_pred),4))
print("MSE:",round(mean_squared_error(y_test,y_pred),4))
# Out:
# R2 score: 0.8151
# MAE: 0.1815
# MSE: 0.0584

# %%
# Support Vector Regressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,4,8])
    ],remainder='passthrough')
step2=SVR(C=100000)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)
print("R2 score:",round(r2_score(y_test,y_pred),4))
print("MAE:",round(mean_absolute_error(y_test,y_pred),4))
print("MSE:",round(mean_squared_error(y_test,y_pred),4))
# Out:
# R2 score: 0.774
# MAE: 0.1867
# MSE: 0.0714

# %%
# AdaBoost Regressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,4,8])
    ],remainder='passthrough')
step2=AdaBoostRegressor()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)
print("R2 score:",round(r2_score(y_test,y_pred),4))
print("MAE:",round(mean_absolute_error(y_test,y_pred),4))
print("MSE:",round(mean_squared_error(y_test,y_pred),4))
# Out:
# R2 score: 0.7918
# MAE: 0.2034
# MSE: 0.0657

# %%
# Random Forest Regressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,4,8])
    ],remainder='passthrough')
step2=RandomForestRegressor()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)
print("R2 score:",round(r2_score(y_test,y_pred),4))
print("MAE:",round(mean_absolute_error(y_test,y_pred),4))
print("MSE:",round(mean_squared_error(y_test,y_pred),4))
# Out:
# R2 score: 0.8753
# MAE: 0.1543
# MSE: 0.0394

# %%
# eXtreme Gradient Boosting Regressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,4,8])
    ],remainder='passthrough')
step2=XGBRegressor()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)
print("R2 score:",round(r2_score(y_test,y_pred),4))
print("MAE:",round(mean_absolute_error(y_test,y_pred),4))
print("MSE:",round(mean_squared_error(y_test,y_pred),4))
# Out:
# R2 score: 0.873
# MAE: 0.147
# MSE: 0.0401

# %%
# Gradient Boosting Regressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,4,8])
    ],remainder='passthrough')
step2=GradientBoostingRegressor(n_estimators=500)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)
print("R2 score:",round(r2_score(y_test,y_pred),4))
print("MAE:",round(mean_absolute_error(y_test,y_pred),4))
print("MSE:",round(mean_squared_error(y_test,y_pred),4))
# Out:
# R2 score: 0.8813
# MAE: 0.145
# MSE: 0.0375

# %%
df.sample()
# Out:
#     Company  TypeName  Ram     Gpu                    OpSys  Weight  Price  \
# 296    Acer  Notebook    8  Nvidia  Linux/Android/Chrome OS     2.5  86063
#
#      Touchscreen  IPS            CPU  HDD  SSD     PPI
# 296            0    0  Intel Core i7    0  256  141.21

# %%
#Deploy

# %%
import pickle
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
# !pip install streamlit --quiet

# %%
# %%writefile app.py
import streamlit as st
import pickle
import numpy as np

df=pickle.load(open('df.pkl','rb'))
pipe=pickle.load(open('pipe.pkl','rb'))

st.title("Laptop Price Predictor")
company=st.selectbox("Brand",df['Company'].unique(),index=4)
type=st.selectbox("Laptop Type",df['TypeName'].unique(),index=1)
ram=st.selectbox("RAM (in GB)",[2,4,6,8,12,16,24,32,64,128],index=3)
gpu=st.selectbox("GPU",df['Gpu'].unique(),index=0)
os=st.selectbox("Operating System",df['OpSys'].unique(),index=2)
weight=st.slider("Weight of the laptop(in kg)",min_value=0.65,max_value=5.0,value=2.0,step=0.5)
touchscreen=st.selectbox("Touchscreen",['Yes','No'],index=1)
ips=st.selectbox("IPS Display",["Yes","No"],index=0)
cpu=st.selectbox("Processor",df['CPU'].unique(),index=0)
hdd=st.selectbox("Hard drive size(in GB)(Select 0 if only SSD is present on the laptop)",
[0,128,256,512,1024,2048],index=0)
ssd=st.selectbox("SSD size(in GB)",[0,8,16,32,64,128,180,240,256,512,768,1024,2048],index=9)
screen_size=st.slider("Screen size(in inches)",min_value=10.0,max_value=18.5,value=15.6,step=0.1)
resolution=st.selectbox("Screen Resolution",
["2560x1600","1440x900","1920x1080","2880x1800","1366x768","2304x1440","3200x1800","1920x1200",
"2256x1504","3840x2160","2160x1440","2560x1440","1600x900","2736x1824","2400x1600"],index=2)

if st.button("PREDICT PRICE"):
    ppi=None
    if(touchscreen=="Yes"):
        touchscreen=1
    else:
        touchscreen=0
    if(ips=="Yes"):
        ips=1
    else:
        ips=0
    X_res=int(resolution.split('x')[0])
    Y_res=int(resolution.split('x')[1])
    ppi=((X_res**2)+(Y_res**2))**0.5/screen_size
    query=np.array([[company,type,ram,gpu,os,weight,touchscreen,ips,cpu,hdd,ssd,ppi]])
    op=np.exp(pipe.predict(query))
    st.subheader("The predicted price of the laptop with the above configuration is ₹"+str(round(op[0])))
# Out:
# Overwriting app.py

# %%
df.describe()
# Out:
#                Ram       Weight          Price  Touchscreen          IPS  \
# count  1224.000000  1224.000000    1224.000000  1224.000000  1224.000000
# mean      8.405229     2.063204   98861.733660     0.138072     0.276961
# std       5.026748     0.663863   58886.596537     0.345116     0.447680
# min       2.000000     0.690000   15296.000000     0.000000     0.000000
# 25%       4.000000     1.597500   53879.500000     0.000000     0.000000
# 50%       8.000000     2.060000   86063.000000     0.000000     0.000000
# 75%       8.000000     2.320000  129886.750000     0.000000     1.000000
# max      64.000000     4.700000  430671.000000     1.000000     1.000000
#
#                HDD          SSD          PPI
# count  1224.000000  1224.000000  1224.000000
# mean    429.026144   183.813725   145.675874
# std     521.196453   183.961543    42.045198
# min       0.000000     0.000000    90.580000
# 25%       0.000000     0.000000   127.340000
# 50%       0.000000   256.000000   141.210000
# 75%    1000.000000   256.000000   157.350000
# max    2000.000000  1024.000000   352.470000

# %%
df['Ram'].unique()
# Out:
# array([ 8, 16,  4,  2, 12,  6, 32, 24, 64])

# %%
df['TypeName'].unique()
# Out:
# array(['Ultrabook', 'Notebook', 'Netbook', 'Gaming', '2 in 1 Convertible',
#        'Workstation'], dtype=object)

# %%
df['Company'].unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'MSI', 'Toshiba'],
#       dtype=object)

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.125.167.252:8501
#
# npx: installed 22 in 2.209s
# your url is: https://fuzzy-brooms-show.loca.lt
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
#   Stopping...
# ^C
